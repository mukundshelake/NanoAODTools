# %%
filePath= '/mnt/disk1/skimmed_Run2/selection/midNov/UL2017/MC_mu/ttbar_SemiLeptonic/tree_194_Skim.root'

# %%
import uproot
import numpy as np

file = uproot.open(filePath)
tree = file['Events']

# %%
for key in tree.keys():
    for k in ['MuonIDWeight', 'MuonHLTWeight', 'LHEWeightSign', 'bTaggingWeight', 'jetPUIdWeight']:
        if k in key:
            array = tree[key].array(library='np')
            max_val = np.max(array)
            min_val = np.min(array)
            mean_val = np.mean(array)
            std_val = np.std(array)
            print(f"{key}: max={max_val}, min={min_val}, mean={mean_val}, std={std_val}")
# Out:
# LHEWeightSign: max=1.0, min=-1.0, mean=0.9932980537414551, std=0.1155812069773674
# MuonIDWeight: max=0.9913614988327026, min=0.9677621722221375, mean=0.9871570467948914, std=0.0038636955432593822
# MuonIDWeightUp: max=0.9918567538261414, min=0.9746471047401428, mean=0.988198459148407, std=0.003360552480444312
# MuonIDWeightDown: max=0.9911122918128967, min=0.9598823189735413, mean=0.9861158132553101, std=0.004579785745590925
# MuonHLTWeight: max=1.0473893880844116, min=0.8612068295478821, mean=0.9803065657615662, std=0.02188847027719021
# MuonHLTWeightStat: max=0.015180387534201145, min=0.0001517797791166231, mean=0.0007318375864997506, std=0.0009875412797555327
# MuonHLTWeightSyst: max=0.0038109496235847473, min=3.788650064961985e-05, mean=0.0005619629519060254, std=0.00043114443542435765
# bTaggingWeight: max=2.0605990886688232, min=0.7750071883201599, mean=0.9226030707359314, std=0.0715857595205307
# bTaggingWeightUp: max=2.968296527862549, min=0.4042585492134094, mean=0.9394448399543762, std=0.11136176437139511
# bTaggingWeightDown: max=1.9382805824279785, min=0.44538986682891846, mean=0.9027270078659058, std=0.11572611331939697
# jetPUIdWeight: max=1235814830833664.0, min=-44499828.0, mean=21538826240.0, std=4933912887296.0
# jetPUIdWeightUp: max=120552375189504.0, min=-4265216049152.0, mean=2298588160.0, std=488109244416.0
# jetPUIdWeightDown: max=4510298165739520.0, min=0.0, mean=73522741248.0, std=17936754409472.0

# %%
import socket

hostname = socket.gethostname()
print("Hostname:", hostname)

if hostname == "my-laptop":
    print("Running on Laptop")
elif hostname == "my-server":
    print("Running on Server")
# Out:
# Hostname: ehep154.ehep.tifr.res.in

# %%
      # - lheWeightSign
      # - muonHLT
      # - bTagging
      # - jetPUID
